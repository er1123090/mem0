# %%
import pandas as pd

data = pd.read_csv('questions_32k.csv')

# %%
data.columns
# Out:
# Index(['persona_id', 'question_id', 'question_type', 'topic',
#        'context_length_in_tokens', 'context_length_in_letters',
#        'distance_to_ref_in_blocks', 'distance_to_ref_in_tokens',
#        'num_irrelevant_tokens', 'distance_to_ref_proportion_in_context',
#        'user_question_or_message', 'correct_answer', 'all_options',
#        'shared_context_id', 'end_index_in_shared_context'],
#       dtype='object')

# %%
data.head(5)
# Out:
#    persona_id                           question_id  \
# 0           0  acd74206-37dc-4756-94a8-b99a395d9a21
# 1           0  f546a74f-54de-40d0-9d88-8b0e30467d7b
# 2           0  b3588797-acdf-40d3-bcc5-951f81896f95
# 3           0  5370f186-0028-41f4-b436-c48575899fca
# 4           0  a40d5f67-8ec6-480b-a901-9709eecee9b9
#
#                                    question_type                topic  \
# 0                       recall_user_shared_facts  musicRecommendation
# 1     provide_preference_aligned_recommendations  musicRecommendation
# 2                              suggest_new_ideas  musicRecommendation
# 3                              suggest_new_ideas  musicRecommendation
# 4  recalling_the_reasons_behind_previous_updates  musicRecommendation
#
#    context_length_in_tokens  context_length_in_letters  \
# 0                     26989                     152394
# 1                     26989                     152394
# 2                     26986                     152394
# ...
